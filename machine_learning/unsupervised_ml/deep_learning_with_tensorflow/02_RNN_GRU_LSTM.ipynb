# %% [markdown]
# ## RNN (Recurent Neural Network) - LSTM (Long Short Term Memory) - GRU (Gated Recurent Unit)
#
# ## RNN

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, SimpleRNN
from tensorflow.keras.models import Sequential
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Generate example data
X = np.random.rand(100, 10, 1)
y = np.random.randint(0, 2, size=(100,))

# %%
X.shape, y.shape
# Out:
# ((100, 10, 1), (100,))

# %%
# Define the model
model = Sequential([
    SimpleRNN(32, input_shape=(10, 1)),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X, y, epochs=10, batch_size=32)

# Evaluate the model
loss, accuracy = model.evaluate(X, y)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 2s 10ms/step - loss: 0.6675 - accuracy: 0.6000
# Epoch 2/10
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6601 - accuracy: 0.6100
# Epoch 3/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6591 - accuracy: 0.6400
# Epoch 4/10
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6580 - accuracy: 0.6400
# Epoch 5/10
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6557 - accuracy: 0.6300
# Epoch 6/10
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6539 - accuracy: 0.6200
# Epoch 7/10
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6520 - accuracy: 0.6000
# Epoch 8/10
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6497 - accuracy: 0.5900
# Epoch 9/10
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6491 - accuracy: 0.5900
# Epoch 10/10
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6479 - accuracy: 0.6000
# 4/4 [==============================] - 0s 0s/step - loss: 0.6458 - accuracy: 0.5900
# Test Loss: 0.6457648277282715
# Test Accuracy: 0.5899999737739563

# %% [markdown]
# ### LSTM (Long Short Term Memory) is a special kind of RNN, capable of learning long-term dependencies.

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.models import Sequential

# Load flight data
flights = sns.load_dataset('flights')

# Convert data to time series
df = pd.DataFrame({'value': flights['passengers'].values}, index=pd.date_range(start='1949-01-01', end='1960-12-01', freq='MS'))
df.head()
# Out:
#             value
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121

# %%
# Split data into training and testing sets
train_size = int(len(df) * 0.8)
train_data, test_data = df.iloc[:train_size], df.iloc[train_size:]

# Normalize the data
train_mean = train_data.mean()
train_std = train_data.std()
train_data = (train_data - train_mean) / train_std
test_data = (test_data - train_mean) / train_std

# Convert data to sequences
def to_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data)-seq_length-1):
        X_seq = data[i:(i+seq_length)].values
        X.append(X_seq)
        y_seq = data.iloc[i+seq_length].values[0]
        y.append(y_seq)
    return np.array(X), np.array(y)

seq_length = 12
X_train, y_train = to_sequences(train_data, seq_length)
X_test, y_test = to_sequences(test_data, seq_length)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Define the model
model = Sequential([
    LSTM(32, input_shape=(seq_length, 1)),
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32)

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print('Test Loss:', loss)

# Make predictions on test data
y_pred = model.predict(X_test)

# Plot the predictions and actual values
import matplotlib.pyplot as plt
plt.plot(test_data.index[seq_length+1:], y_test, label='Actual')
plt.plot(test_data.index[seq_length+1:], y_pred, label='Predicted')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 2s 6ms/step - loss: 0.8148
# Epoch 2/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6811
# Epoch 3/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5651
# Epoch 4/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4598
# Epoch 5/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3710
# Epoch 6/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2991
# Epoch 7/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2401
# Epoch 8/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2032
# Epoch 9/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1814
# Epoch 10/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1765
# Epoch 11/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1782
# Epoch 12/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1769
# Epoch 13/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1739
# Epoch 14/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1683
# Epoch 15/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1649
# Epoch 16/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1614
# Epoch 17/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1615
# Epoch 18/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1607
# Epoch 19/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1596
# Epoch 20/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1582
# Epoch 21/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1569
# Epoch 22/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1555
# Epoch 23/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1551
# Epoch 24/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1544
# Epoch 25/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1529
# Epoch 26/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1521
# Epoch 27/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1512
# Epoch 28/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1506
# Epoch 29/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1521
# Epoch 30/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1517
# Epoch 31/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1504
# Epoch 32/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1485
# Epoch 33/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1469
# Epoch 34/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1470
# Epoch 35/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1466
# Epoch 36/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1458
# Epoch 37/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1446
# Epoch 38/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1454
# Epoch 39/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1450
# Epoch 40/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1439
# Epoch 41/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1420
# Epoch 42/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1397
# Epoch 43/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1377
# Epoch 44/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1374
# Epoch 45/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1363
# Epoch 46/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1344
# Epoch 47/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1357
# Epoch 48/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1355
# Epoch 49/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1342
# Epoch 50/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1329
# Epoch 51/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1306
# Epoch 52/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1300
# Epoch 53/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1311
# Epoch 54/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1295
# Epoch 55/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1271
# Epoch 56/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1261
# Epoch 57/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1247
# Epoch 58/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1241
# Epoch 59/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1228
# Epoch 60/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1207
# Epoch 61/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1182
# Epoch 62/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1197
# Epoch 63/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1200
# Epoch 64/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1170
# Epoch 65/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1154
# Epoch 66/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1152
# Epoch 67/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1118
# Epoch 68/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1117
# Epoch 69/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1090
# Epoch 70/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1064
# Epoch 71/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1036
# Epoch 72/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1028
# Epoch 73/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1019
# Epoch 74/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0964
# Epoch 75/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0933
# Epoch 76/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0928
# Epoch 77/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0880
# Epoch 78/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0834
# Epoch 79/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0817
# Epoch 80/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0783
# Epoch 81/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0730
# Epoch 82/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0714
# Epoch 83/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0668
# Epoch 84/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0654
# Epoch 85/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0609
# Epoch 86/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0586
# Epoch 87/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0546
# Epoch 88/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0521
# Epoch 89/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0495
# Epoch 90/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0569
# Epoch 91/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0485
# Epoch 92/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0471
# Epoch 93/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0440
# Epoch 94/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0427
# Epoch 95/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0456
# Epoch 96/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0388
# Epoch 97/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0491
# Epoch 98/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0439
# Epoch 99/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0384
# Epoch 100/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0420
# 1/1 [==============================] - 0s 397ms/step - loss: 0.8090
# Test Loss: 0.8089854121208191
# 1/1 [==============================] - 0s 374ms/step

# %% [markdown]
# ### let's build a simple RNN-based character-level text generator using a sample text. We'll use a sequence-to-sequence prediction approach to predict the next character in a sequence.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Sample text data
text = "hello world! this is a simple text example for rnn."
chars = sorted(list(set(text))) # Get unique characters
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# Create input-output sequences
seq_length = 10
X = []
y = []

for i in range(len(text) - seq_length):
    seq_in = text[i:i + seq_length]
    seq_out = text[i + seq_length]
    X.append([char_to_int[char] for char in seq_in])
    y.append(char_to_int[seq_out])

X = np.reshape(X, (len(X), seq_length, 1)) / float(len(chars)) # Normalize
y = tf.keras.utils.to_categorical(y)

# Define model
model = Sequential([
    LSTM(128, input_shape=(X.shape[1], X.shape[2])),
    Dense(len(chars), activation='softmax')
])

# Compile and train
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=100, batch_size=10, verbose=1)

# Predict a sequence
start = np.random.randint(0, len(X)-1)
pattern = X[start]
print("Seed:")
print("\"", ''.join([int_to_char[int(value*len(chars))] for value in pattern]), "\"")

for i in range(50): # Generate 50 characters
    x = np.reshape(pattern, (1, len(pattern), 1))
    prediction = model.predict(x, verbose=1)
    index = np.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[int(value*len(chars))] for value in pattern]
    print(result, end="")
    pattern = np.append(pattern, index/float(len(chars)))
    pattern = pattern[1:len(pattern)]

print("\n")
# Out:
# Epoch 1/100
# 5/5 [==============================] - 3s 8ms/step - loss: 2.9393
# Epoch 2/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.9022
# Epoch 3/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.8807
# Epoch 4/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.8564
# Epoch 5/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.8055
# Epoch 6/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.7517
# Epoch 7/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.7218
# Epoch 8/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.7850
# Epoch 9/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.7319
# Epoch 10/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.7441
# Epoch 11/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.7416
# Epoch 12/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7332
# Epoch 13/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7213
# Epoch 14/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.7229
# Epoch 15/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.7141
# Epoch 16/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.7095
# Epoch 17/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.7111
# Epoch 18/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.7206
# Epoch 19/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.7212
# Epoch 20/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.7123
# Epoch 21/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.7080
# Epoch 22/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.7068
# Epoch 23/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.7060
# Epoch 24/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.7089
# Epoch 25/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.7105
# Epoch 26/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.7096
# Epoch 27/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.7078
# Epoch 28/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.7121
# Epoch 29/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.7044
# Epoch 30/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.7061
# Epoch 31/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.7055
# Epoch 32/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7043
# Epoch 33/100
# 5/5 [==============================] - 0s 3ms/step - loss: 2.7010
# Epoch 34/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6991
# Epoch 35/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.7046
# Epoch 36/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.7088
# Epoch 37/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6950
# Epoch 38/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.6968
# Epoch 39/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.7066
# Epoch 40/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.7111
# Epoch 41/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.7119
# Epoch 42/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.7114
# Epoch 43/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.7068
# Epoch 44/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.7074
# Epoch 45/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.7027
# Epoch 46/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6997
# Epoch 47/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6950
# Epoch 48/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.6928
# Epoch 49/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.6962
# Epoch 50/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.7084
# Epoch 51/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.7121
# Epoch 52/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.7134
# Epoch 53/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.7014
# Epoch 54/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.6989
# Epoch 55/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.6921
# Epoch 56/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.7037
# Epoch 57/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.6971
# Epoch 58/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.6874
# Epoch 59/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6909
# Epoch 60/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6831
# Epoch 61/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.7075
# Epoch 62/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.7099
# Epoch 63/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.7002
# Epoch 64/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6901
# Epoch 65/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6874
# Epoch 66/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.6870
# Epoch 67/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6865
# Epoch 68/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6807
# Epoch 69/100
# 5/5 [==============================] - 0s 19ms/step - loss: 2.6815
# Epoch 70/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6801
# Epoch 71/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6859
# Epoch 72/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6933
# Epoch 73/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.6855
# Epoch 74/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6783
# Epoch 75/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.6819
# Epoch 76/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.6821
# Epoch 77/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6775
# Epoch 78/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.6828
# Epoch 79/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6813
# Epoch 80/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.6800
# Epoch 81/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6837
# Epoch 82/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.6867
# Epoch 83/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.6809
# Epoch 84/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.6765
# Epoch 85/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6768
# Epoch 86/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.6904
# Epoch 87/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6925
# Epoch 88/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.6802
# Epoch 89/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.6879
# Epoch 90/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6733
# Epoch 91/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.6723
# Epoch 92/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.6720
# Epoch 93/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.6691
# Epoch 94/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.6617
# Epoch 95/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.6596
# Epoch 96/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.6615
# Epoch 97/100
# 5/5 [==============================] - 0s 77ms/step - loss: 2.6699
# Epoch 98/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6745
# Epoch 99/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6747
# Epoch 100/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.6738
# Seed:
# " imple text "
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step

# %% [markdown]
# Here, we first convert our sample text into sequences of characters. Each sequence of characters (X) corresponds to a next character (y). The model is trained to predict y from X.
#
# After training, we take a random seed sequence and use the model to predict the next 50 characters. The output will show the initial seed and the generated text based on it.

# %% [markdown]
# ### GRU (Gated Recurrent Unit) is a variation of LSTM. It has fewer parameters than LSTM, as it lacks an output gate.

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, GRU  # Note the change here
from tensorflow.keras.models import Sequential

# Load flight data
flights = sns.load_dataset('flights')

# Convert data to time series
df = pd.DataFrame({'value': flights['passengers'].values}, index=pd.date_range(start='1949-01-01', end='1960-12-01', freq='MS'))

# Split data into training and testing sets
train_size = int(len(df) * 0.8)
train_data, test_data = df.iloc[:train_size], df.iloc[train_size:]

# Normalize the data
train_mean = train_data.mean()
train_std = train_data.std()
train_data = (train_data - train_mean) / train_std
test_data = (test_data - train_mean) / train_std

# Convert data to sequences
def to_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data)-seq_length-1):
        X_seq = data[i:(i+seq_length)].values
        X.append(X_seq)
        y_seq = data.iloc[i+seq_length].values[0]
        y.append(y_seq)
    return np.array(X), np.array(y)

seq_length = 12
X_train, y_train = to_sequences(train_data, seq_length)
X_test, y_test = to_sequences(test_data, seq_length)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Define the model using GRU
model = Sequential([
    GRU(32, input_shape=(seq_length, 1)),  # Note the change here
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32)

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print('Test Loss:', loss)

# Make predictions on test data
y_pred = model.predict(X_test)

# Plot the predictions and actual values
import matplotlib.pyplot as plt
plt.plot(test_data.index[seq_length+1:], y_test, label='Actual')
plt.plot(test_data.index[seq_length+1:], y_pred, label='Predicted')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 2s 4ms/step - loss: 0.8752
# Epoch 2/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7374
# Epoch 3/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5990
# Epoch 4/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4914
# Epoch 5/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4000
# Epoch 6/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3228
# Epoch 7/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2581
# Epoch 8/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2199
# Epoch 9/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1900
# Epoch 10/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1746
# Epoch 11/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1721
# Epoch 12/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1711
# Epoch 13/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1733
# Epoch 14/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1709
# Epoch 15/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1656
# Epoch 16/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1602
# Epoch 17/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1576
# Epoch 18/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1556
# Epoch 19/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1540
# Epoch 20/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1519
# Epoch 21/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1502
# Epoch 22/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1482
# Epoch 23/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1463
# Epoch 24/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1448
# Epoch 25/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1444
# Epoch 26/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1430
# Epoch 27/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1408
# Epoch 28/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1383
# Epoch 29/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1364
# Epoch 30/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1348
# Epoch 31/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1333
# Epoch 32/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1324
# Epoch 33/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1315
# Epoch 34/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1300
# Epoch 35/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1290
# Epoch 36/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1275
# Epoch 37/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1258
# Epoch 38/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1251
# Epoch 39/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1238
# Epoch 40/100
# 4/4 [==============================] - 0s 884us/step - loss: 0.1226
# Epoch 41/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1217
# Epoch 42/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1199
# Epoch 43/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1191
# Epoch 44/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1177
# Epoch 45/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1172
# Epoch 46/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1161
# Epoch 47/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1148
# Epoch 48/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1136
# Epoch 49/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1129
# Epoch 50/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1116
# Epoch 51/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1107
# Epoch 52/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1095
# Epoch 53/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1082
# Epoch 54/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1066
# Epoch 55/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1058
# Epoch 56/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1043
# Epoch 57/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1035
# Epoch 58/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1016
# Epoch 59/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1001
# Epoch 60/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0989
# Epoch 61/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0987
# Epoch 62/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0991
# Epoch 63/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0972
# Epoch 64/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0940
# Epoch 65/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0909
# Epoch 66/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0899
# Epoch 67/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0888
# Epoch 68/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0869
# Epoch 69/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0867
# Epoch 70/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0858
# Epoch 71/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0835
# Epoch 72/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0822
# Epoch 73/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0808
# Epoch 74/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0796
# Epoch 75/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0776
# Epoch 76/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0771
# Epoch 77/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0759
# Epoch 78/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0751
# Epoch 79/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0738
# Epoch 80/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0724
# Epoch 81/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0733
# Epoch 82/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0718
# Epoch 83/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0700
# Epoch 84/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0676
# Epoch 85/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0673
# Epoch 86/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0652
# Epoch 87/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0653
# Epoch 88/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0640
# Epoch 89/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0649
# Epoch 90/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0658
# Epoch 91/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0628
# Epoch 92/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0595
# Epoch 93/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0590
# Epoch 94/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0580
# Epoch 95/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0567
# Epoch 96/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0562
# Epoch 97/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0547
# Epoch 98/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0555
# Epoch 99/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0573
# Epoch 100/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0542
# 1/1 [==============================] - 0s 353ms/step - loss: 0.5583
# Test Loss: 0.558309018611908
# 1/1 [==============================] - 0s 359ms/step

# %% [markdown]
# ### GRU on Text

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense  # Import GRU instead of LSTM

# Sample text data
text = "hello world! this is a simple text example for rnn."
chars = sorted(list(set(text)))  # Get unique characters
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# Create input-output sequences
seq_length = 10
X = []
y = []

for i in range(len(text) - seq_length):
    seq_in = text[i:i + seq_length]
    seq_out = text[i + seq_length]
    X.append([char_to_int[char] for char in seq_in])
    y.append(char_to_int[seq_out])

X = np.reshape(X, (len(X), seq_length, 1)) / float(len(chars))  # Normalize
y = tf.keras.utils.to_categorical(y)

# Define model using GRU
model = Sequential([
    GRU(128, input_shape=(X.shape[1], X.shape[2])),  # Change LSTM to GRU here
    Dense(len(chars), activation='softmax')
])

# Compile and train
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=100, batch_size=10, verbose=1)

# Predict a sequence
start = np.random.randint(0, len(X)-1)
pattern = X[start]
print("Seed:")
print("\"", ''.join([int_to_char[int(value*len(chars))] for value in pattern]), "\"")

for i in range(50):  # Generate 50 characters
    x = np.reshape(pattern, (1, len(pattern), 1))
    prediction = model.predict(x, verbose=0)
    index = np.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[int(value*len(chars))] for value in pattern]
    print(result, end="")
    pattern = np.append(pattern, index/float(len(chars)))
    pattern = pattern[1:len(pattern)]

print("\n")
# Out:
# Epoch 1/100
# 5/5 [==============================] - 2s 4ms/step - loss: 2.9407
# Epoch 2/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.9057
# Epoch 3/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.8777
# Epoch 4/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.8553
# Epoch 5/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8336
# Epoch 6/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.8100
# Epoch 7/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.7743
# Epoch 8/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.7460
# Epoch 9/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.7693
# Epoch 10/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.7260
# Epoch 11/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.7259
# Epoch 12/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.7190
# Epoch 13/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.7182
# Epoch 14/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.7166
# Epoch 15/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.7191
# Epoch 16/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7152
# Epoch 17/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.7164
# Epoch 18/100
# 5/5 [==============================] - 0s 2ms/step - loss: 2.7099
# Epoch 19/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.6991
# Epoch 20/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.7183
# Epoch 21/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.7344
# Epoch 22/100
# 5/5 [==============================] - 0s 3ms/step - loss: 2.7007
# Epoch 23/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7113
# Epoch 24/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.7066
# Epoch 25/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.7023
# Epoch 26/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.7021
# Epoch 27/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6973
# Epoch 28/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6962
# Epoch 29/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.6986
# Epoch 30/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.6882
# Epoch 31/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.6918
# Epoch 32/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6976
# Epoch 33/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.6948
# Epoch 34/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.6910
# Epoch 35/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.6832
# Epoch 36/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.6809
# Epoch 37/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.6807
# Epoch 38/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.6836
# Epoch 39/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.6795
# Epoch 40/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.6840
# Epoch 41/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6815
# Epoch 42/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6796
# Epoch 43/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6772
# Epoch 44/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.6849
# Epoch 45/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6921
# Epoch 46/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.6900
# Epoch 47/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.7110
# Epoch 48/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.6920
# Epoch 49/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6656
# Epoch 50/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6697
# Epoch 51/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.6686
# Epoch 52/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6686
# Epoch 53/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.6614
# Epoch 54/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.6555
# Epoch 55/100
# 5/5 [==============================] - 0s 2ms/step - loss: 2.6617
# Epoch 56/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.6595
# Epoch 57/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.6505
# Epoch 58/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.6520
# Epoch 59/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.6479
# Epoch 60/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.6490
# Epoch 61/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.6393
# Epoch 62/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.6330
# Epoch 63/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.6321
# Epoch 64/100
# 5/5 [==============================] - 0s 2ms/step - loss: 2.6330
# Epoch 65/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.6268
# Epoch 66/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.6219
# Epoch 67/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.6220
# Epoch 68/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.5990
# Epoch 69/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.5864
# Epoch 70/100
# 5/5 [==============================] - 0s 3ms/step - loss: 2.5701
# Epoch 71/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.5635
# Epoch 72/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.5552
# Epoch 73/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.5266
# Epoch 74/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.5021
# Epoch 75/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.4967
# Epoch 76/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.4669
# Epoch 77/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.4552
# Epoch 78/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.4240
# Epoch 79/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.4159
# Epoch 80/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.4166
# Epoch 81/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.3744
# Epoch 82/100
# 5/5 [==============================] - 0s 3ms/step - loss: 2.3248
# Epoch 83/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.3070
# Epoch 84/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.3147
# Epoch 85/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.3064
# Epoch 86/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.3303
# Epoch 87/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.2848
# Epoch 88/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.2213
# Epoch 89/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.2151
# Epoch 90/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.1756
# Epoch 91/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.1570
# Epoch 92/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.1538
# Epoch 93/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.1001
# Epoch 94/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.0882
# Epoch 95/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.0759
# Epoch 96/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.0254
# Epoch 97/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.0689
# Epoch 98/100
# 5/5 [==============================] - 0s 8ms/step - loss: 2.0241
# Epoch 99/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.0966
# Epoch 100/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.9891
# Seed:
# " rld! this  "
# e thmp e thmp e thmp e thmp e thmp e thmp e thmp e
