# %% [markdown]
# ## Overfitting vs. Underfitting
#
# ### 1. Setup and Baseline Model

# %%
# %%time
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.callbacks import EarlyStopping

# ignore warnings in the output
import warnings
warnings.filterwarnings("ignore")

# Load data
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Define a simple model
def create_model():
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(128, activation='relu'),
        Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

model = create_model()

# Train the baseline model
history_baseline = model.fit(x_train, y_train, epochs=10, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 2.8885 - accuracy: 0.8506 - val_loss: 0.5804 - val_accuracy: 0.8747
# Epoch 2/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.4305 - accuracy: 0.9002 - val_loss: 0.3744 - val_accuracy: 0.9123
# Epoch 3/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3273 - accuracy: 0.9187 - val_loss: 0.3258 - val_accuracy: 0.9212
# Epoch 4/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2791 - accuracy: 0.9283 - val_loss: 0.3217 - val_accuracy: 0.9281
# Epoch 5/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2473 - accuracy: 0.9371 - val_loss: 0.3399 - val_accuracy: 0.9223
# Epoch 6/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2309 - accuracy: 0.9417 - val_loss: 0.2761 - val_accuracy: 0.9374
# Epoch 7/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2151 - accuracy: 0.9452 - val_loss: 0.2847 - val_accuracy: 0.9433
# Epoch 8/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2098 - accuracy: 0.9480 - val_loss: 0.2761 - val_accuracy: 0.9413
# Epoch 9/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1892 - accuracy: 0.9519 - val_loss: 0.2881 - val_accuracy: 0.9423
# Epoch 10/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1913 - accuracy: 0.9527 - val_loss: 0.2968 - val_accuracy: 0.9402
# CPU times: total: 10.7 s
# Wall time: 51.9 s

# %% [markdown]
# ### 2. Run model on Normalized Data

# %%
# %%time
# laod and normalize the data
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# Define a model for normalized data
def create_model_with_norm_data():
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(128, activation='relu'),
        Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

model_with_norm_data = create_model_with_norm_data()

# Train the baseline model
history_norm_data = model_with_norm_data.fit(x_train, y_train, epochs=10, validation_split=0.2, verbose=1)

# plot the effect of normalization
plt.plot(history_baseline.history['val_accuracy'], label='Baseline Validation Accuracy')
plt.plot(history_norm_data.history['val_accuracy'], label = 'Normalized Validation Accuracy')
plt.title('Effect of Normalization')
plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2809 - accuracy: 0.9200 - val_loss: 0.1508 - val_accuracy: 0.9577
# Epoch 2/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.1229 - accuracy: 0.9641 - val_loss: 0.1231 - val_accuracy: 0.9628
# Epoch 3/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0834 - accuracy: 0.9749 - val_loss: 0.0945 - val_accuracy: 0.9721
# Epoch 4/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0613 - accuracy: 0.9819 - val_loss: 0.0935 - val_accuracy: 0.9710
# Epoch 5/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0466 - accuracy: 0.9859 - val_loss: 0.0861 - val_accuracy: 0.9741
# Epoch 6/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0360 - accuracy: 0.9889 - val_loss: 0.0986 - val_accuracy: 0.9722
# Epoch 7/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0289 - accuracy: 0.9916 - val_loss: 0.0806 - val_accuracy: 0.9766
# Epoch 8/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0220 - accuracy: 0.9938 - val_loss: 0.0872 - val_accuracy: 0.9763
# Epoch 9/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0186 - accuracy: 0.9945 - val_loss: 0.0998 - val_accuracy: 0.9745
# Epoch 10/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0158 - accuracy: 0.9955 - val_loss: 0.0950 - val_accuracy: 0.9761
# CPU times: total: 7.36 s
# Wall time: 40.3 s

# %% [markdown]
# ### 3. Adding Dropout
#
# Now, let's modify the model to include dropout and observe its effect.

# %%
# Define a model with dropout
def create_model_with_dropout():
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.5),  # Adding dropout
        Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

model_with_dropout = create_model_with_dropout()

# Train the model with dropout
history_dropout = model_with_dropout.fit(x_train, y_train, epochs=10, validation_split=0.2, verbose=1)

# Plotting the effect of dropout
plt.plot(history_baseline.history['val_accuracy'], label='Baseline Validation Accuracy')
# plot line for normalized data
plt.plot(history_norm_data.history['val_accuracy'], label='Normalized Validation Accuracy')
plt.plot(history_dropout.history['val_accuracy'], label='With Dropout Validation Accuracy')
plt.title('Effect of Dropout on Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.4229 - accuracy: 0.8745 - val_loss: 0.1871 - val_accuracy: 0.9461
# Epoch 2/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2401 - accuracy: 0.9292 - val_loss: 0.1434 - val_accuracy: 0.9602
# Epoch 3/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1958 - accuracy: 0.9419 - val_loss: 0.1206 - val_accuracy: 0.9650
# Epoch 4/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.1719 - accuracy: 0.9474 - val_loss: 0.1092 - val_accuracy: 0.9696
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1582 - accuracy: 0.9526 - val_loss: 0.1024 - val_accuracy: 0.9710
# Epoch 6/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.1456 - accuracy: 0.9556 - val_loss: 0.1016 - val_accuracy: 0.9712
# Epoch 7/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1379 - accuracy: 0.9569 - val_loss: 0.0958 - val_accuracy: 0.9728
# Epoch 8/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1269 - accuracy: 0.9600 - val_loss: 0.0933 - val_accuracy: 0.9731
# Epoch 9/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1238 - accuracy: 0.9612 - val_loss: 0.0915 - val_accuracy: 0.9739
# Epoch 10/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1150 - accuracy: 0.9643 - val_loss: 0.0907 - val_accuracy: 0.9745

# %% [markdown]
# ### 4. Early Stopping
# Finally, we will use early stopping to stop training when the validation loss starts to increase.

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=3)

model_with_es = create_model_with_norm_data()

# train with early stop
history_es = model_with_es.fit(x_train, y_train, epochs=10, validation_split=0.2, verbose=1, callbacks=[early_stopping])

# plot the effect of early stopping
plt.plot(history_baseline.history['val_accuracy'], label='Baseline Validation Accuracy')
# plot line for normalized data
plt.plot(history_norm_data.history['val_accuracy'], label='Normalized Validation Accuracy')
plt.plot(history_dropout.history['val_accuracy'], label='With Dropout Validation Accuracy')
plt.plot(history_es.history['val_accuracy'], label='With Early Stopping Validation Accuracy')
plt.title('Effect of Early Stopping on Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2890 - accuracy: 0.9169 - val_loss: 0.1609 - val_accuracy: 0.9538
# Epoch 2/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.1284 - accuracy: 0.9624 - val_loss: 0.1165 - val_accuracy: 0.9653
# Epoch 3/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0876 - accuracy: 0.9735 - val_loss: 0.1036 - val_accuracy: 0.9712
# Epoch 4/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0655 - accuracy: 0.9803 - val_loss: 0.0913 - val_accuracy: 0.9728
# Epoch 5/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0500 - accuracy: 0.9847 - val_loss: 0.0869 - val_accuracy: 0.9741
# Epoch 6/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0393 - accuracy: 0.9879 - val_loss: 0.0905 - val_accuracy: 0.9736
# Epoch 7/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0309 - accuracy: 0.9910 - val_loss: 0.0890 - val_accuracy: 0.9753
# Epoch 8/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0251 - accuracy: 0.9925 - val_loss: 0.0883 - val_accuracy: 0.9763

# %% [markdown]
# 5. L1/L2 Regularization
# L1 and L2 regularization are two common regularization techniques that can be used to reduce overfitting.
#
# L1 in Keras: kernel_regularizer=regularizers.l1(0.001) L2 in Keras: kernel_regularizer=regularizers.l2(0.001)
#
# L1 changes the loss function by adding the sum of the absolute weights to it. L2 changes the loss function by adding the sum of the squared weights to it.
#
# - L1 make zero some of the weights.
# - L2 make the weights small.

# %%
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l1, l2, l1_l2
import matplotlib.pyplot as plt

# Define a model with L1 regularization
def create_model_with_l1():
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(128, activation='relu', kernel_regularizer=l1(0.0001)),  # L1 regularization
        Dropout(0.5), # Adding dropout which will also be regularized by L1
        Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Define a model with L2 regularization
def create_model_with_l2():
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(128, activation='relu', kernel_regularizer=l2(0.0001)),  # L2 regularization
        Dropout(0.5), # Adding dropout which will also be regularized by L2
        Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# should we combine them both?
# Define a model with L1_L2 (combined) regularization
def create_model_with_l1_l2():
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(128, activation='relu', kernel_regularizer=l1_l2(l1=0.0001, l2=0.0001)),  # L1_L2 regularization
        Dropout(0.5), # Adding dropout which will also be regularized by L1_L2
        Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Prepare and train the models
model_with_l1 = create_model_with_l1()
history_l1 = model_with_l1.fit(x_train, y_train, epochs=10, validation_split=0.2, verbose=1)

model_with_l2 = create_model_with_l2()
history_l2 = model_with_l2.fit(x_train, y_train, epochs=10, validation_split=0.2, verbose=1)

model_with_l1_l2 = create_model_with_l1_l2()
history_l1_l2 = model_with_l1_l2.fit(x_train, y_train, epochs=10, validation_split=0.2, verbose=1)

# Plotting the effect of regularization
# plot line for normalized data
plt.plot(history_norm_data.history['val_accuracy'], label='Normalized Validation Accuracy')
plt.plot(history_dropout.history['val_accuracy'], label='With Dropout Validation Accuracy')
plt.plot(history_l1.history['val_accuracy'], label='With L1 Regularization Validation Accuracy')
plt.plot(history_l2.history['val_accuracy'], label='With L2 Regularization Validation Accuracy')
plt.plot(history_l1_l2.history['val_accuracy'], label='With L1_L2 Regularization Validation Accuracy')
plt.title('Effect of Regularization on Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.6596 - accuracy: 0.8679 - val_loss: 0.3862 - val_accuracy: 0.9460
# Epoch 2/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.4452 - accuracy: 0.9216 - val_loss: 0.3294 - val_accuracy: 0.9551
# Epoch 3/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.4002 - accuracy: 0.9331 - val_loss: 0.3016 - val_accuracy: 0.9617
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3818 - accuracy: 0.9355 - val_loss: 0.2848 - val_accuracy: 0.9673
# Epoch 5/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.3641 - accuracy: 0.9404 - val_loss: 0.2836 - val_accuracy: 0.9672
# Epoch 6/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.3589 - accuracy: 0.9422 - val_loss: 0.2798 - val_accuracy: 0.9688
# Epoch 7/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.3507 - accuracy: 0.9450 - val_loss: 0.2713 - val_accuracy: 0.9695
# Epoch 8/10
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.3486 - accuracy: 0.9450 - val_loss: 0.2674 - val_accuracy: 0.9696
# Epoch 9/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.3446 - accuracy: 0.9445 - val_loss: 0.2655 - val_accuracy: 0.9705
# Epoch 10/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.3375 - accuracy: 0.9471 - val_loss: 0.2633 - val_accuracy: 0.9718
# Epoch 1/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.4562 - accuracy: 0.8709 - val_loss: 0.2143 - val_accuracy: 0.9471
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2759 - accuracy: 0.9282 - val_loss: 0.1754 - val_accuracy: 0.9582
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2410 - accuracy: 0.9390 - val_loss: 0.1552 - val_accuracy: 0.9662
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2238 - accuracy: 0.9428 - val_loss: 0.1447 - val_accuracy: 0.9688
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2111 - accuracy: 0.9489 - val_loss: 0.1475 - val_accuracy: 0.9689
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2061 - accuracy: 0.9506 - val_loss: 0.1467 - val_accuracy: 0.9706
# Epoch 7/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1967 - accuracy: 0.9531 - val_loss: 0.1413 - val_accuracy: 0.9728
# Epoch 8/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1924 - accuracy: 0.9550 - val_loss: 0.1412 - val_accuracy: 0.9717
# Epoch 9/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1923 - accuracy: 0.9548 - val_loss: 0.1383 - val_accuracy: 0.9718
# Epoch 10/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1887 - accuracy: 0.9559 - val_loss: 0.1380 - val_accuracy: 0.9742
# Epoch 1/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.6634 - accuracy: 0.8662 - val_loss: 0.3892 - val_accuracy: 0.9432
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4542 - accuracy: 0.9197 - val_loss: 0.3415 - val_accuracy: 0.9519
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4145 - accuracy: 0.9278 - val_loss: 0.3060 - val_accuracy: 0.9609
# Epoch 4/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.3903 - accuracy: 0.9348 - val_loss: 0.2948 - val_accuracy: 0.9617
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3797 - accuracy: 0.9367 - val_loss: 0.2890 - val_accuracy: 0.9643
# Epoch 6/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.3725 - accuracy: 0.9390 - val_loss: 0.2762 - val_accuracy: 0.9678
# Epoch 7/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.3629 - accuracy: 0.9405 - val_loss: 0.2784 - val_accuracy: 0.9684
# Epoch 8/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.3607 - accuracy: 0.9413 - val_loss: 0.2754 - val_accuracy: 0.9683
# Epoch 9/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.3549 - accuracy: 0.9427 - val_loss: 0.2716 - val_accuracy: 0.9704
# Epoch 10/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.3516 - accuracy: 0.9435 - val_loss: 0.2668 - val_accuracy: 0.9699

# %%
# Plotting the effect of regularization
# plot line for normalized data
# plt.plot(history_norm_data.history['val_accuracy'], label='Normalized Validation Accuracy')
# plt.plot(history_dropout.history['val_accuracy'], label='With Dropout Validation Accuracy')
plt.plot(history_l1.history['val_accuracy'], label='With L1 Regularization Validation Accuracy')
plt.plot(history_l2.history['val_accuracy'], label='With L2 Regularization Validation Accuracy')
plt.plot(history_l1_l2.history['val_accuracy'], label='With L1_L2 Regularization Validation Accuracy')
plt.title('Effect of Regularization on Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### 6. K-fold cross validation
#
# k-fold cross-validation in TensorFlow requires a bit more manual setup compared to libraries like scikit-learn, which offer built-in k-fold cross-validation functions. TensorFlow does not have a direct function for k-fold cross-validation, but you can achieve this by manually splitting your dataset into k folds and then training and evaluating your model on each fold.
#
# Below is an example code that demonstrates how to perform k-fold cross-validation with the MNIST dataset in TensorFlow. This example uses a simple neural network similar to the ones discussed previously.

# %%
# %%time
import numpy as np
from sklearn.model_selection import KFold
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.utils import to_categorical

# Load data
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0  # Normalize data
y_train = to_categorical(y_train, 10)  # One-hot encode labels

# Define a simple model architecture function
def create_model():
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(128, activation='relu'),
        Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Prepare for k-fold cross-validation
k = 5  # Number of folds
kf = KFold(n_splits=k, shuffle=True)

# Arrays to store scores
fold_idx = 1
scores = []

for train_index, val_index in kf.split(x_train):
    # Split data
    x_train_fold, x_val_fold = x_train[train_index], x_train[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
    
    # create a model
    model_kfold_cv = create_model()
    
    # Train model
    history_kfold_cv = model_kfold_cv.fit(x_train_fold, y_train_fold, epochs=10, validation_data=(x_val_fold, y_val_fold), verbose=1)
    
    # Append the last score from the history
    scores.append((history_kfold_cv.history['val_loss'][-1], history_kfold_cv.history['val_accuracy'][-1]))

# Calculate and print average performance across all folds
average_loss, average_accuracy = np.mean(scores, axis=0)
print(f'\nK-Fold Validation Results:\nAverage Loss: {average_loss}, Average Accuracy: {average_accuracy}')

# Plotting
folds = range(1, k + 1)
val_losses, val_accuracies = zip(*scores)

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.plot(folds, val_losses, 'o-', label='Validation Loss')
plt.plot(folds, [average_loss] * k, 'r--', label='Average Loss')
plt.title('Validation Loss per Fold')
plt.xlabel('Fold')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(folds, val_accuracies, 'o-', label='Validation Accuracy')
plt.plot(folds, [average_accuracy] * k, 'r--', label='Average Accuracy')
plt.title('Validation Accuracy per Fold')
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2913 - accuracy: 0.9177 - val_loss: 0.1712 - val_accuracy: 0.9488
# Epoch 2/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1305 - accuracy: 0.9625 - val_loss: 0.1334 - val_accuracy: 0.9549
# Epoch 3/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0886 - accuracy: 0.9738 - val_loss: 0.1048 - val_accuracy: 0.9682
# Epoch 4/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0641 - accuracy: 0.9807 - val_loss: 0.0887 - val_accuracy: 0.9706
# Epoch 5/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.0505 - accuracy: 0.9851 - val_loss: 0.0905 - val_accuracy: 0.9729
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0394 - accuracy: 0.9882 - val_loss: 0.0853 - val_accuracy: 0.9736
# Epoch 7/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0326 - accuracy: 0.9901 - val_loss: 0.0860 - val_accuracy: 0.9748
# Epoch 8/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0259 - accuracy: 0.9922 - val_loss: 0.0952 - val_accuracy: 0.9722
# Epoch 9/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0202 - accuracy: 0.9940 - val_loss: 0.0785 - val_accuracy: 0.9765
# Epoch 10/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0151 - accuracy: 0.9955 - val_loss: 0.0836 - val_accuracy: 0.9756
# Epoch 1/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2802 - accuracy: 0.9197 - val_loss: 0.1565 - val_accuracy: 0.9562
# Epoch 2/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.1233 - accuracy: 0.9638 - val_loss: 0.1119 - val_accuracy: 0.9654
# Epoch 3/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0837 - accuracy: 0.9750 - val_loss: 0.1068 - val_accuracy: 0.9688
# Epoch 4/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0621 - accuracy: 0.9817 - val_loss: 0.0833 - val_accuracy: 0.9755
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0474 - accuracy: 0.9851 - val_loss: 0.0907 - val_accuracy: 0.9732
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0374 - accuracy: 0.9882 - val_loss: 0.0829 - val_accuracy: 0.9746
# Epoch 7/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0291 - accuracy: 0.9914 - val_loss: 0.0880 - val_accuracy: 0.9737
# Epoch 8/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0238 - accuracy: 0.9928 - val_loss: 0.0951 - val_accuracy: 0.9718
# Epoch 9/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0185 - accuracy: 0.9945 - val_loss: 0.0925 - val_accuracy: 0.9740
# Epoch 10/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0157 - accuracy: 0.9952 - val_loss: 0.0941 - val_accuracy: 0.9732
# Epoch 1/10
# 1500/1500 [==============================] - 6s 3ms/step - loss: 0.2813 - accuracy: 0.9193 - val_loss: 0.1678 - val_accuracy: 0.9507
# Epoch 2/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1264 - accuracy: 0.9643 - val_loss: 0.1213 - val_accuracy: 0.9653
# Epoch 3/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0857 - accuracy: 0.9741 - val_loss: 0.1010 - val_accuracy: 0.9696
# Epoch 4/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0645 - accuracy: 0.9795 - val_loss: 0.0984 - val_accuracy: 0.9725
# Epoch 5/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0486 - accuracy: 0.9850 - val_loss: 0.0915 - val_accuracy: 0.9726
# Epoch 6/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0391 - accuracy: 0.9883 - val_loss: 0.0943 - val_accuracy: 0.9719
# Epoch 7/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0295 - accuracy: 0.9914 - val_loss: 0.0946 - val_accuracy: 0.9729
# Epoch 8/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0238 - accuracy: 0.9932 - val_loss: 0.0857 - val_accuracy: 0.9758
# Epoch 9/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0196 - accuracy: 0.9942 - val_loss: 0.0990 - val_accuracy: 0.9737
# Epoch 10/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0149 - accuracy: 0.9957 - val_loss: 0.1040 - val_accuracy: 0.9737
# Epoch 1/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2787 - accuracy: 0.9204 - val_loss: 0.1640 - val_accuracy: 0.9507
# Epoch 2/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1296 - accuracy: 0.9617 - val_loss: 0.1225 - val_accuracy: 0.9646
# Epoch 3/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0886 - accuracy: 0.9733 - val_loss: 0.1126 - val_accuracy: 0.9663
# Epoch 4/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0664 - accuracy: 0.9803 - val_loss: 0.1046 - val_accuracy: 0.9686
# Epoch 5/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0499 - accuracy: 0.9853 - val_loss: 0.0854 - val_accuracy: 0.9739
# Epoch 6/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0405 - accuracy: 0.9879 - val_loss: 0.0847 - val_accuracy: 0.9744
# Epoch 7/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0311 - accuracy: 0.9909 - val_loss: 0.0943 - val_accuracy: 0.9728
# Epoch 8/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0252 - accuracy: 0.9922 - val_loss: 0.0933 - val_accuracy: 0.9746
# Epoch 9/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0200 - accuracy: 0.9941 - val_loss: 0.0924 - val_accuracy: 0.9747
# Epoch 10/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0174 - accuracy: 0.9949 - val_loss: 0.0920 - val_accuracy: 0.9754
# Epoch 1/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2840 - accuracy: 0.9193 - val_loss: 0.1661 - val_accuracy: 0.9523
# Epoch 2/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1271 - accuracy: 0.9618 - val_loss: 0.1208 - val_accuracy: 0.9665
# Epoch 3/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0887 - accuracy: 0.9735 - val_loss: 0.1172 - val_accuracy: 0.9659
# Epoch 4/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0656 - accuracy: 0.9802 - val_loss: 0.0965 - val_accuracy: 0.9732
# Epoch 5/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0497 - accuracy: 0.9854 - val_loss: 0.0918 - val_accuracy: 0.9735
# Epoch 6/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0379 - accuracy: 0.9880 - val_loss: 0.0940 - val_accuracy: 0.9743
# Epoch 7/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0306 - accuracy: 0.9909 - val_loss: 0.0936 - val_accuracy: 0.9750
# Epoch 8/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0229 - accuracy: 0.9931 - val_loss: 0.0985 - val_accuracy: 0.9735
# Epoch 9/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0190 - accuracy: 0.9947 - val_loss: 0.1000 - val_accuracy: 0.9730
# Epoch 10/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0162 - accuracy: 0.9951 - val_loss: 0.0949 - val_accuracy: 0.9766
#
# K-Fold Validation Results:
# Average Loss: 0.09372499287128448, Average Accuracy: 0.9749166607856751
# CPU times: total: 55.8 s
# Wall time: 3min 56s

# %% [markdown]
# This code performs the following steps:
#
# 1. Normalizes the data and one-hot encodes the labels.
# 2. Defines a simple neural network model inside a function so that a fresh model can be created for each fold.
# 3. Uses KFold from sklearn.model_selection to generate train/validation splits.
# 4. Trains a new model instance on each train fold and evaluates it on the corresponding validation fold.
# 5. Calculates and prints the average loss and accuracy across all folds at the end.
#
# Remember, k-fold cross-validation can be computationally expensive since it involves training and evaluating k separate models. Adjust the number of epochs, model complexity, or the dataset size as necessary to manage the computational load.
