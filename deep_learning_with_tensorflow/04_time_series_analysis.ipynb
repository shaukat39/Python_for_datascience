# %% [markdown]
# ## Time series analysis on the data International Airline passengers from 1940 to 1960

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# data fetch from github
df = pd.read_csv("AirPassengers.csv")
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df.shape
# Out:
# (144, 2)

# %%
# plot this data to see trends and seasonality with seaborn
sns.lineplot(x="Month", y="#Passengers", data=df)
# Out:
# <Axes: xlabel='Month', ylabel='#Passengers'>

# %%
# decompose the data into trend, seasonality and residuals
decompose = seasonal_decompose(df["#Passengers"], model="multiplicative", period=12)
decompose.plot()

# %%
decompose.seasonal.plot()
# Out:
# <Axes: >

# %%
trend = decompose.trend
seasonal = decompose.seasonal
residual = decompose.resid

# %%
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.metrics import RootMeanSquaredError

# split the data into training and testing sets
train_size = int(len(df) * 0.8)
train = df[:train_size]
test = df[train_size:]

# define the number of lagged time steps to use as input features
n_lags = 12

# create the input and output data for the neural network
X_train = np.array([train["#Passengers"].values[i:i+n_lags] for i in range(len(train)-n_lags)])
y_train = np.array(train["#Passengers"].values[n_lags:])
X_test = np.array([test["#Passengers"].values[i:i+n_lags] for i in range(len(test)-n_lags)])
y_test = np.array(test["#Passengers"].values[n_lags:])

# create the neural network model
model = Sequential()
model.add(Dense(10, input_dim=n_lags, activation="relu"))
model.add(Dense(1))
model.compile(loss="mean_squared_error", optimizer="adam", metrics=[RootMeanSquaredError()])

# train the neural network model
model.fit(X_train, y_train, epochs=100, batch_size=10, verbose=1)

# make predictions on the testing set using the trained model
predictions = model.predict(X_test)

# plot the actual and predicted values
plt.plot(test.index[-len(predictions):], test["#Passengers"].values[-len(predictions):], label="actual")
plt.plot(test.index[-len(predictions):], predictions, label="predicted")
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 11/11 [==============================] - 1s 2ms/step - loss: 5386.2700 - root_mean_squared_error: 73.3912
# Epoch 2/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2261.2478 - root_mean_squared_error: 47.5526
# Epoch 3/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1690.7308 - root_mean_squared_error: 41.1185
# Epoch 4/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1588.2700 - root_mean_squared_error: 39.8531
# Epoch 5/100
# 11/11 [==============================] - 0s 2ms/step - loss: 1465.2294 - root_mean_squared_error: 38.2783
# Epoch 6/100
# 11/11 [==============================] - 0s 2ms/step - loss: 1385.4858 - root_mean_squared_error: 37.2221
# Epoch 7/100
# 11/11 [==============================] - 0s 2ms/step - loss: 1311.7200 - root_mean_squared_error: 36.2177
# Epoch 8/100
# 11/11 [==============================] - 0s 2ms/step - loss: 1215.0814 - root_mean_squared_error: 34.8580
# Epoch 9/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1151.9675 - root_mean_squared_error: 33.9406
# Epoch 10/100
# 11/11 [==============================] - 0s 2ms/step - loss: 1088.2623 - root_mean_squared_error: 32.9888
# Epoch 11/100
# 11/11 [==============================] - 0s 2ms/step - loss: 1019.6356 - root_mean_squared_error: 31.9317
# Epoch 12/100
# 11/11 [==============================] - 0s 2ms/step - loss: 946.1229 - root_mean_squared_error: 30.7591
# Epoch 13/100
# 11/11 [==============================] - 0s 2ms/step - loss: 903.2279 - root_mean_squared_error: 30.0538
# Epoch 14/100
# 11/11 [==============================] - 0s 2ms/step - loss: 832.8523 - root_mean_squared_error: 28.8592
# Epoch 15/100
# 11/11 [==============================] - 0s 2ms/step - loss: 795.9185 - root_mean_squared_error: 28.2120
# Epoch 16/100
# 11/11 [==============================] - 0s 2ms/step - loss: 755.6503 - root_mean_squared_error: 27.4891
# Epoch 17/100
# 11/11 [==============================] - 0s 2ms/step - loss: 738.5905 - root_mean_squared_error: 27.1770
# Epoch 18/100
# 11/11 [==============================] - 0s 2ms/step - loss: 698.3260 - root_mean_squared_error: 26.4259
# Epoch 19/100
# 11/11 [==============================] - 0s 2ms/step - loss: 711.4466 - root_mean_squared_error: 26.6730
# Epoch 20/100
# 11/11 [==============================] - 0s 3ms/step - loss: 688.7203 - root_mean_squared_error: 26.2435
# Epoch 21/100
# 11/11 [==============================] - 0s 4ms/step - loss: 629.1900 - root_mean_squared_error: 25.0837
# Epoch 22/100
# 11/11 [==============================] - 0s 2ms/step - loss: 661.4102 - root_mean_squared_error: 25.7179
# Epoch 23/100
# 11/11 [==============================] - 0s 1ms/step - loss: 570.4311 - root_mean_squared_error: 23.8837
# Epoch 24/100
# 11/11 [==============================] - 0s 2ms/step - loss: 561.6677 - root_mean_squared_error: 23.6995
# Epoch 25/100
# 11/11 [==============================] - 0s 2ms/step - loss: 558.2435 - root_mean_squared_error: 23.6272
# Epoch 26/100
# 11/11 [==============================] - 0s 2ms/step - loss: 556.4443 - root_mean_squared_error: 23.5891
# Epoch 27/100
# 11/11 [==============================] - 0s 2ms/step - loss: 552.9789 - root_mean_squared_error: 23.5155
# Epoch 28/100
# 11/11 [==============================] - 0s 2ms/step - loss: 557.6701 - root_mean_squared_error: 23.6150
# Epoch 29/100
# 11/11 [==============================] - 0s 2ms/step - loss: 551.5780 - root_mean_squared_error: 23.4857
# Epoch 30/100
# 11/11 [==============================] - 0s 2ms/step - loss: 477.6352 - root_mean_squared_error: 21.8549
# Epoch 31/100
# 11/11 [==============================] - 0s 1ms/step - loss: 475.9692 - root_mean_squared_error: 21.8167
# Epoch 32/100
# 11/11 [==============================] - 0s 2ms/step - loss: 504.0628 - root_mean_squared_error: 22.4513
# Epoch 33/100
# 11/11 [==============================] - 0s 2ms/step - loss: 522.8352 - root_mean_squared_error: 22.8656
# Epoch 34/100
# 11/11 [==============================] - 0s 1ms/step - loss: 506.5638 - root_mean_squared_error: 22.5070
# Epoch 35/100
# 11/11 [==============================] - 0s 2ms/step - loss: 489.9994 - root_mean_squared_error: 22.1359
# Epoch 36/100
# 11/11 [==============================] - 0s 2ms/step - loss: 522.6380 - root_mean_squared_error: 22.8613
# Epoch 37/100
# 11/11 [==============================] - 0s 2ms/step - loss: 457.8205 - root_mean_squared_error: 21.3967
# Epoch 38/100
# 11/11 [==============================] - 0s 1ms/step - loss: 468.5909 - root_mean_squared_error: 21.6470
# Epoch 39/100
# 11/11 [==============================] - 0s 1ms/step - loss: 436.1055 - root_mean_squared_error: 20.8831
# Epoch 40/100
# 11/11 [==============================] - 0s 2ms/step - loss: 428.9766 - root_mean_squared_error: 20.7118
# Epoch 41/100
# 11/11 [==============================] - 0s 2ms/step - loss: 445.3297 - root_mean_squared_error: 21.1028
# Epoch 42/100
# 11/11 [==============================] - 0s 1ms/step - loss: 423.4178 - root_mean_squared_error: 20.5771
# Epoch 43/100
# 11/11 [==============================] - 0s 2ms/step - loss: 417.8449 - root_mean_squared_error: 20.4413
# Epoch 44/100
# 11/11 [==============================] - 0s 2ms/step - loss: 416.1829 - root_mean_squared_error: 20.4006
# Epoch 45/100
# 11/11 [==============================] - 0s 2ms/step - loss: 405.8688 - root_mean_squared_error: 20.1462
# Epoch 46/100
# 11/11 [==============================] - 0s 2ms/step - loss: 424.2723 - root_mean_squared_error: 20.5979
# Epoch 47/100
# 11/11 [==============================] - 0s 2ms/step - loss: 406.8748 - root_mean_squared_error: 20.1711
# Epoch 48/100
# 11/11 [==============================] - 0s 2ms/step - loss: 392.6389 - root_mean_squared_error: 19.8151
# Epoch 49/100
# 11/11 [==============================] - 0s 2ms/step - loss: 394.3718 - root_mean_squared_error: 19.8588
# Epoch 50/100
# 11/11 [==============================] - 0s 2ms/step - loss: 389.0678 - root_mean_squared_error: 19.7248
# Epoch 51/100
# 11/11 [==============================] - 0s 2ms/step - loss: 410.8454 - root_mean_squared_error: 20.2693
# Epoch 52/100
# 11/11 [==============================] - 0s 1ms/step - loss: 400.6061 - root_mean_squared_error: 20.0151
# Epoch 53/100
# 11/11 [==============================] - 0s 2ms/step - loss: 381.3679 - root_mean_squared_error: 19.5286
# Epoch 54/100
# 11/11 [==============================] - 0s 2ms/step - loss: 390.6879 - root_mean_squared_error: 19.7658
# Epoch 55/100
# 11/11 [==============================] - 0s 2ms/step - loss: 375.4767 - root_mean_squared_error: 19.3772
# Epoch 56/100
# 11/11 [==============================] - 0s 2ms/step - loss: 376.2510 - root_mean_squared_error: 19.3972
# Epoch 57/100
# 11/11 [==============================] - 0s 2ms/step - loss: 382.4896 - root_mean_squared_error: 19.5573
# Epoch 58/100
# 11/11 [==============================] - 0s 1ms/step - loss: 381.1352 - root_mean_squared_error: 19.5227
# Epoch 59/100
# 11/11 [==============================] - 0s 2ms/step - loss: 382.1190 - root_mean_squared_error: 19.5479
# Epoch 60/100
# 11/11 [==============================] - 0s 2ms/step - loss: 368.0446 - root_mean_squared_error: 19.1845
# Epoch 61/100
# 11/11 [==============================] - 0s 2ms/step - loss: 435.5652 - root_mean_squared_error: 20.8702
# Epoch 62/100
# 11/11 [==============================] - 0s 2ms/step - loss: 390.9283 - root_mean_squared_error: 19.7719
# Epoch 63/100
# 11/11 [==============================] - 0s 2ms/step - loss: 372.6378 - root_mean_squared_error: 19.3038
# Epoch 64/100
# 11/11 [==============================] - 0s 2ms/step - loss: 374.1681 - root_mean_squared_error: 19.3434
# Epoch 65/100
# 11/11 [==============================] - 0s 2ms/step - loss: 385.7954 - root_mean_squared_error: 19.6417
# Epoch 66/100
# 11/11 [==============================] - 0s 4ms/step - loss: 355.2845 - root_mean_squared_error: 18.8490
# Epoch 67/100
# 11/11 [==============================] - 0s 2ms/step - loss: 353.0061 - root_mean_squared_error: 18.7885
# Epoch 68/100
# 11/11 [==============================] - 0s 2ms/step - loss: 347.7940 - root_mean_squared_error: 18.6492
# Epoch 69/100
# 11/11 [==============================] - 0s 2ms/step - loss: 345.6380 - root_mean_squared_error: 18.5913
# Epoch 70/100
# 11/11 [==============================] - 0s 2ms/step - loss: 346.3495 - root_mean_squared_error: 18.6105
# Epoch 71/100
# 11/11 [==============================] - 0s 2ms/step - loss: 345.2775 - root_mean_squared_error: 18.5816
# Epoch 72/100
# 11/11 [==============================] - 0s 2ms/step - loss: 366.0485 - root_mean_squared_error: 19.1324
# Epoch 73/100
# 11/11 [==============================] - 0s 2ms/step - loss: 341.2400 - root_mean_squared_error: 18.4727
# Epoch 74/100
# 11/11 [==============================] - 0s 2ms/step - loss: 345.2633 - root_mean_squared_error: 18.5813
# Epoch 75/100
# 11/11 [==============================] - 0s 2ms/step - loss: 343.2483 - root_mean_squared_error: 18.5270
# Epoch 76/100
# 11/11 [==============================] - 0s 2ms/step - loss: 333.0893 - root_mean_squared_error: 18.2507
# Epoch 77/100
# 11/11 [==============================] - 0s 2ms/step - loss: 356.8504 - root_mean_squared_error: 18.8905
# Epoch 78/100
# 11/11 [==============================] - 0s 2ms/step - loss: 371.8181 - root_mean_squared_error: 19.2826
# Epoch 79/100
# 11/11 [==============================] - 0s 2ms/step - loss: 333.3120 - root_mean_squared_error: 18.2568
# Epoch 80/100
# 11/11 [==============================] - 0s 1ms/step - loss: 340.4752 - root_mean_squared_error: 18.4520
# Epoch 81/100
# 11/11 [==============================] - 0s 2ms/step - loss: 338.6861 - root_mean_squared_error: 18.4034
# Epoch 82/100
# 11/11 [==============================] - 0s 2ms/step - loss: 347.1592 - root_mean_squared_error: 18.6322
# Epoch 83/100
# 11/11 [==============================] - 0s 2ms/step - loss: 330.2831 - root_mean_squared_error: 18.1737
# Epoch 84/100
# 11/11 [==============================] - 0s 3ms/step - loss: 324.5786 - root_mean_squared_error: 18.0161
# Epoch 85/100
# 11/11 [==============================] - 0s 1ms/step - loss: 345.5786 - root_mean_squared_error: 18.5897
# Epoch 86/100
# 11/11 [==============================] - 0s 2ms/step - loss: 333.6269 - root_mean_squared_error: 18.2655
# Epoch 87/100
# 11/11 [==============================] - 0s 2ms/step - loss: 358.7109 - root_mean_squared_error: 18.9397
# Epoch 88/100
# 11/11 [==============================] - 0s 2ms/step - loss: 335.5735 - root_mean_squared_error: 18.3187
# Epoch 89/100
# 11/11 [==============================] - 0s 9ms/step - loss: 347.0714 - root_mean_squared_error: 18.6299
# Epoch 90/100
# 11/11 [==============================] - 0s 4ms/step - loss: 355.6962 - root_mean_squared_error: 18.8599
# Epoch 91/100
# 11/11 [==============================] - 0s 2ms/step - loss: 328.9435 - root_mean_squared_error: 18.1368
# Epoch 92/100
# 11/11 [==============================] - 0s 2ms/step - loss: 310.1346 - root_mean_squared_error: 17.6106
# Epoch 93/100
# 11/11 [==============================] - 0s 2ms/step - loss: 308.6768 - root_mean_squared_error: 17.5692
# Epoch 94/100
# 11/11 [==============================] - 0s 2ms/step - loss: 305.6887 - root_mean_squared_error: 17.4840
# Epoch 95/100
# 11/11 [==============================] - 0s 2ms/step - loss: 311.5982 - root_mean_squared_error: 17.6521
# Epoch 96/100
# 11/11 [==============================] - 0s 2ms/step - loss: 305.1560 - root_mean_squared_error: 17.4687
# Epoch 97/100
# 11/11 [==============================] - 0s 2ms/step - loss: 312.8717 - root_mean_squared_error: 17.6882
# Epoch 98/100
# 11/11 [==============================] - 0s 2ms/step - loss: 308.5497 - root_mean_squared_error: 17.5656
# Epoch 99/100
# 11/11 [==============================] - 0s 2ms/step - loss: 299.5721 - root_mean_squared_error: 17.3082
# Epoch 100/100
# 11/11 [==============================] - 0s 2ms/step - loss: 294.5047 - root_mean_squared_error: 17.1611
# 1/1 [==============================] - 0s 105ms/step
